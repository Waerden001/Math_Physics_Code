# %% [markdown]
# # Problems
#
# - Harmonic analysis on complex projective spaces.
# - Tomography: reconstruct 3D images from their plane sections.

# %% [markdown]
# # Mathematics: Radon transform, point-hyperplane duality
#
# References:
#
# - [Radon transform, Wikipedia](https://en.wikipedia.org/wiki/Radon_transform)
#
# - [Radon transform, WolframWolrd](https://mathworld.wolfram.com/RadonTransform.html)
#
# As usual, since we can easily find "definitions" and "facts" in the references, we focus more on
#
# - Intuitive understanding of Radon transform.
# - Have fun solving the problems and understand some of its applications.
# - Compute with Wolfram Language (Radon transform and inverse Radon transform are built in), code to accomplish more complicated goals.

# %% [markdown]
# # Code: Radon transform with Wolfram Language/Mathematica and more

# %%
pic = Import["../Images/pink-heart-1.jpg"]
# Out:
# -Image-

# %%
Radon[pic]
# Out:
# -Image-
